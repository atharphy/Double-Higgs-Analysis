# %%
import ROOT
import os
from ROOT import gROOT
import pandas as pd
import numpy as np
# Out:
# Welcome to JupyROOT 6.24/06

# %%
MakeCsvDataFrame = ROOT.RDF.MakeCsvDataFrame

# %%
tt_trial_1 = MakeCsvDataFrame('/localdata/Athar/CNN/output_files/tt_feature_2.csv')
hh_trial_1 = MakeCsvDataFrame('/localdata/Athar/CNN/output_files/hh_feature_2.csv')
tt_trial_2 = MakeCsvDataFrame('/localdata/Athar/CNN/output_files/tt_feature_3.csv')
hh_trial_2 = MakeCsvDataFrame('/localdata/Athar/CNN/output_files/hh_feature_3.csv')
tt_trial_3 = MakeCsvDataFrame('/localdata/Athar/CNN/output_files/tt_feature_4.csv')
hh_trial_3 = MakeCsvDataFrame('/localdata/Athar/CNN/output_files/hh_feature_4.csv')
tt_trial_4 = MakeCsvDataFrame('/localdata/Athar/CNN/output_files/tt_feature_6.csv')
hh_trial_4 = MakeCsvDataFrame('/localdata/Athar/CNN/output_files/hh_feature_6.csv')
tt_trial_5 = MakeCsvDataFrame('/localdata/Athar/CNN/output_files/tt_feature_7.csv')
hh_trial_5 = MakeCsvDataFrame('/localdata/Athar/CNN/output_files/hh_feature_7.csv')

# %%
#trial 1 (signal) Using variables m,pt,eta,phi,P,pair_dr

cut = np.linspace(0.90, 0.99,30)
Lumi = 3000
# TTbar variables
BR_tt = 0.375  # Total branching ratio for the ttbar process
x_sect_tt = 984500  # fb
total_events_tt = 1_400_000

# HH variables
BR_hh = 0.0937  # Total branching ratio for the hh process
x_sect_hh = 40  # fb
total_events_hh = 900_000

max_sigma = 0
cut_index = 0
sigma_value = []
cut_value = []
signal_events_dict = {}  # Dictionary to store signal event rows for each bin
background_events_dict = {}  # Dictionary to store background event rows for each bin

for i in cut:
    prob_sig_cut = 'prob_sig > {}'.format(i)
    tt_cut = tt_trial_1.Filter(prob_sig_cut)  # Filter signal events
    hh_cut = hh_trial_1.Filter(prob_sig_cut)  # Filter background events

    # Extract relevant data from RDataFrame and convert to pandas DataFrame
    tt_cut_data = tt_cut.AsNumpy()
    tt_cut_df = pd.DataFrame(tt_cut_data)

    hh_cut_data = hh_cut.AsNumpy()
    hh_cut_df = pd.DataFrame(hh_cut_data)

    num_hh = hh_cut.Count().GetValue()
    num_tt = tt_cut.Count().GetValue()
    print('number of tt events: ', num_tt)
    print('number of hh events: ', num_hh)

    accp_tt = num_tt / total_events_tt
    accp_hh = num_hh / total_events_hh
    print('acceptance of hh: ', accp_hh)
    print('acceptance of tt: ', accp_tt)

    # Calculate expected events
    N_exp_tt = Lumi * BR_tt * x_sect_tt * accp_tt
    N_exp_hh = Lumi * BR_hh * x_sect_hh * accp_hh
    print('No. of expected tt events: ', N_exp_tt)
    print('No. of expected hh events: ', N_exp_hh)

    sigma = N_exp_hh / (N_exp_tt)**(1/2)
    print("semi-lepton Sigma: " + str(sigma) + " with a cut > " + str(i))
    sigma_value.append(sigma)
    cut_value.append(i)

    # Store copies of the DataFrames in the dictionaries for each bin
    signal_events_dict[i] = hh_cut_df.copy()
    background_events_dict[i] = tt_cut_df.copy()

    if sigma > max_sigma:
        max_sigma = sigma
        cut_index = i

print('No. of tt events at maximum sigma: ', tt_cut.Count().GetValue())
print('No. of hh events at maximum sigma: ', hh_cut.Count().GetValue())
print('The maximum sigma value is:')
print("semi-lepton Sigma: " + str(max_sigma) + " with a cut > " + str(cut_index))
bb = pd.DataFrame({"cut_value" : cut_value, "sigma_value" : sigma_value})
bb.to_csv("/localdata/Athar/CNN/plot_files/plot_data/feature_2.csv", index=False)


# Save the data for each bin to separate CSV files
for i in cut:
    signal_events_dict[i].to_csv(f"/localdata/Athar/CNN/plot_files/cut_data/cut_1/signal_events_bin_{i}.csv", index=False)
    background_events_dict[i].to_csv(f"/localdata/Athar/CNN/plot_files/cut_data/cut_1/background_events_bin_{i}.csv", index=False)
# Out:
# number of tt events:  1080
# number of hh events:  25675
# acceptance of hh:  0.028527777777777777
# acceptance of tt:  0.0007714285714285715
# No. of expected tt events:  854405.3571428572
# No. of expected hh events:  320.7663333333333
# semi-lepton Sigma: 0.34702183216946664 with a cut > 0.9
# number of tt events:  1026
# number of hh events:  25300
# acceptance of hh:  0.02811111111111111
# acceptance of tt:  0.0007328571428571428
# No. of expected tt events:  811685.0892857143
# No. of expected hh events:  316.0813333333333
# semi-lepton Sigma: 0.350836738224812 with a cut > 0.9031034482758621
# number of tt events:  975
# number of hh events:  24871
# acceptance of hh:  0.027634444444444444
# acceptance of tt:  0.0006964285714285715
# No. of expected tt events:  771338.1696428572
# No. of expected hh events:  310.72169333333335
# semi-lepton Sigma: 0.35379294105164155 with a cut > 0.9062068965517242
# number of tt events:  935
# number of hh events:  24480
# acceptance of hh:  0.0272
# acceptance of tt:  0.0006678571428571429
# No. of expected tt events:  739693.5267857143
# No. of expected hh events:  305.8368
# semi-lepton Sigma: 0.3556017027900917 with a cut > 0.9093103448275862
# number of tt events:  890
# number of hh events:  24057
# acceptance of hh:  0.02673
# acceptance of tt:  0.0006357142857142857
# No. of expected tt events:  704093.3035714285
# No. of expected hh events:  300.55212
# semi-lepton Sigma: 0.35818276835468665 with a cut > 0.9124137931034483
# number of tt events:  830
# number of hh events:  23602
# acceptance of hh:  0.026224444444444446
# acceptance of tt:  0.0005928571428571429
# No. of expected tt events:  656626.3392857143
# No. of expected hh events:  294.86765333333335
# semi-lepton Sigma: 0.3638882092186487 with a cut > 0.9155172413793103
# number of tt events:  787
# number of hh events:  23187
# acceptance of hh:  0.025763333333333333
# acceptance of tt:  0.0005621428571428572
# No. of expected tt events:  622608.3482142858
# No. of expected hh events:  289.68291999999997
# semi-lepton Sigma: 0.36712623434697134 with a cut > 0.9186206896551724
# number of tt events:  748
# number of hh events:  22702
# acceptance of hh:  0.025224444444444445
# acceptance of tt:  0.0005342857142857142
# No. of expected tt events:  591754.8214285714
# No. of expected hh events:  283.6236533333333
# semi-lepton Sigma: 0.3686986473280455 with a cut > 0.9217241379310345
# number of tt events:  705
# number of hh events:  22257
# acceptance of hh:  0.02473
# acceptance of tt:  0.0005035714285714285
# No. of expected tt events:  557736.8303571428
# No. of expected hh events:  278.06412
# semi-lepton Sigma: 0.3723319382756809 with a cut > 0.9248275862068965
# number of tt events:  666
# number of hh events:  21778
# acceptance of hh:  0.024197777777777776
# acceptance of tt:  0.0004757142857142857
# No. of expected tt events:  526883.3035714285
# No. of expected hh events:  272.07981333333333
# semi-lepton Sigma: 0.37483410813318363 with a cut > 0.9279310344827586
# number of tt events:  616
# number of hh events:  21326
# acceptance of hh:  0.023695555555555557
# acceptance of tt:  0.00044
# No. of expected tt events:  487327.5
# No. of expected hh events:  266.4328266666667
# semi-lepton Sigma: 0.3816605507501024 with a cut > 0.9310344827586207
# number of tt events:  577
# number of hh events:  20818
# acceptance of hh:  0.023131111111111113
# acceptance of tt:  0.0004121428571428571
# No. of expected tt events:  456473.9732142857
# No. of expected hh events:  260.0862133333334
# semi-lepton Sigma: 0.384954429738388 with a cut > 0.9341379310344827
# number of tt events:  534
# number of hh events:  20288
# acceptance of hh:  0.022542222222222224
# acceptance of tt:  0.0003814285714285714
# No. of expected tt events:  422455.9821428571
# No. of expected hh events:  253.46474666666668
# semi-lepton Sigma: 0.3899660787987339 with a cut > 0.9372413793103448
# number of tt events:  505
# number of hh events:  19732
# acceptance of hh:  0.021924444444444444
# acceptance of tt:  0.0003607142857142857
# No. of expected tt events:  399513.6160714286
# No. of expected hh events:  246.51845333333333
# semi-lepton Sigma: 0.3900170935820977 with a cut > 0.9403448275862069
# number of tt events:  473
# number of hh events:  19181
# acceptance of hh:  0.021312222222222222
# acceptance of tt:  0.00033785714285714284
# No. of expected tt events:  374197.90178571426
# No. of expected hh events:  239.63462666666666
# semi-lepton Sigma: 0.3917408838424585 with a cut > 0.943448275862069
# number of tt events:  434
# number of hh events:  18572
# acceptance of hh:  0.020635555555555556
# acceptance of tt:  0.00031
# No. of expected tt events:  343344.375
# No. of expected hh events:  232.0261866666667
# semi-lepton Sigma: 0.3959788901907827 with a cut > 0.9465517241379311
# number of tt events:  408
# number of hh events:  17953
# acceptance of hh:  0.019947777777777776
# acceptance of tt:  0.00029142857142857144
# No. of expected tt events:  322775.35714285716
# No. of expected hh events:  224.29281333333333
# semi-lepton Sigma: 0.39478911798319577 with a cut > 0.9496551724137932
# number of tt events:  366
# number of hh events:  17291
# acceptance of hh:  0.01921222222222222
# acceptance of tt:  0.0002614285714285714
# No. of expected tt events:  289548.4821428571
# No. of expected hh events:  216.02222666666665
# semi-lepton Sigma: 0.4014558510633201 with a cut > 0.9527586206896552
# number of tt events:  331
# number of hh events:  16593
# acceptance of hh:  0.018436666666666667
# acceptance of tt:  0.00023642857142857143
# No. of expected tt events:  261859.41964285716
# No. of expected hh events:  207.30188
# semi-lepton Sigma: 0.40510643340794694 with a cut > 0.9558620689655173
# number of tt events:  302
# number of hh events:  15889
# acceptance of hh:  0.017654444444444445
# acceptance of tt:  0.00021571428571428571
# No. of expected tt events:  238917.05357142858
# No. of expected hh events:  198.50657333333334
# semi-lepton Sigma: 0.40611713845316666 with a cut > 0.9589655172413794
# number of tt events:  277
# number of hh events:  15128
# acceptance of hh:  0.01680888888888889
# acceptance of tt:  0.00019785714285714285
# No. of expected tt events:  219139.1517857143
# No. of expected hh events:  188.9991466666667
# semi-lepton Sigma: 0.4037382118238667 with a cut > 0.9620689655172414
# number of tt events:  251
# number of hh events:  14316
# acceptance of hh:  0.015906666666666666
# acceptance of tt:  0.0001792857142857143
# No. of expected tt events:  198570.13392857142
# No. of expected hh events:  178.85456
# semi-lepton Sigma: 0.4013682850746095 with a cut > 0.9651724137931035
# number of tt events:  219
# number of hh events:  13471
# acceptance of hh:  0.014967777777777778
# acceptance of tt:  0.00015642857142857144
# No. of expected tt events:  173254.41964285716
# No. of expected hh events:  168.29769333333334
# semi-lepton Sigma: 0.40433003425337494 with a cut > 0.9682758620689655
# number of tt events:  197
# number of hh events:  12620
# acceptance of hh:  0.014022222222222222
# acceptance of tt:  0.0001407142857142857
# No. of expected tt events:  155849.86607142855
# No. of expected hh events:  157.66586666666666
# semi-lepton Sigma: 0.3993783015426732 with a cut > 0.9713793103448276
# number of tt events:  162
# number of hh events:  11628
# acceptance of hh:  0.01292
# acceptance of tt:  0.00011571428571428571
# No. of expected tt events:  128160.80357142857
# No. of expected hh events:  145.27248
# semi-lepton Sigma: 0.4057941105925874 with a cut > 0.9744827586206897
# number of tt events:  131
# number of hh events:  10626
# acceptance of hh:  0.011806666666666667
# acceptance of tt:  9.357142857142857e-05
# No. of expected tt events:  103636.20535714286
# No. of expected hh events:  132.75416
# semi-lepton Sigma: 0.41237505608568575 with a cut > 0.9775862068965517
# number of tt events:  104
# number of hh events:  9537
# acceptance of hh:  0.010596666666666667
# acceptance of tt:  7.428571428571429e-05
# No. of expected tt events:  82276.07142857143
# No. of expected hh events:  119.14892
# semi-lepton Sigma: 0.41538741718918765 with a cut > 0.9806896551724138
# number of tt events:  81
# number of hh events:  8287
# acceptance of hh:  0.009207777777777778
# acceptance of tt:  5.7857142857142855e-05
# No. of expected tt events:  64080.40178571428
# No. of expected hh events:  103.53225333333334
# semi-lepton Sigma: 0.4089903426485348 with a cut > 0.9837931034482759
# number of tt events:  58
# number of hh events:  6880
# acceptance of hh:  0.007644444444444444
# acceptance of tt:  4.142857142857143e-05
# No. of expected tt events:  45884.732142857145
# No. of expected hh events:  85.95413333333333
# semi-lepton Sigma: 0.40126627958639 with a cut > 0.9868965517241379
# number of tt events:  39
# number of hh events:  5418
# acceptance of hh:  0.00602
# acceptance of tt:  2.7857142857142858e-05
# No. of expected tt events:  30853.526785714286
# No. of expected hh events:  67.68888
# semi-lepton Sigma: 0.3853584806838876 with a cut > 0.99
# No. of tt events at maximum sigma:  39
# No. of hh events at maximum sigma:  5418
# The maximum sigma value is:
# semi-lepton Sigma: 0.41538741718918765 with a cut > 0.9806896551724138

# %%
#trial 2 (signal) Using variables m,pt,eta,phi,pair_dr,Hness,Tness

cut = np.linspace(0.90, 0.99,30)
Lumi = 3000
# TTbar variables
BR_tt = 0.375  # Total branching ratio for the ttbar process
x_sect_tt = 984500  # fb
total_events_tt = 1_400_000

# HH variables
BR_hh = 0.0937  # Total branching ratio for the hh process
x_sect_hh = 40  # fb
total_events_hh = 900_000

max_sigma = 0
cut_index = 0
sigma_value = []
cut_value = []
signal_events_dict = {}  # Dictionary to store signal event rows for each bin
background_events_dict = {}  # Dictionary to store background event rows for each bin

for i in cut:
    prob_sig_cut = 'prob_sig > {}'.format(i)
    tt_cut = tt_trial_2.Filter(prob_sig_cut)  # Filter signal events
    hh_cut = hh_trial_2.Filter(prob_sig_cut)  # Filter background events

    # Extract relevant data from RDataFrame and convert to pandas DataFrame
    tt_cut_data = tt_cut.AsNumpy()
    tt_cut_df = pd.DataFrame(tt_cut_data)

    hh_cut_data = hh_cut.AsNumpy()
    hh_cut_df = pd.DataFrame(hh_cut_data)

    num_hh = hh_cut.Count().GetValue()
    num_tt = tt_cut.Count().GetValue()
    print('number of tt events: ', num_tt)
    print('number of hh events: ', num_hh)

    accp_tt = num_tt / total_events_tt
    accp_hh = num_hh / total_events_hh
    print('acceptance of hh: ', accp_hh)
    print('acceptance of tt: ', accp_tt)

    # Calculate expected events
    N_exp_tt = Lumi * BR_tt * x_sect_tt * accp_tt
    N_exp_hh = Lumi * BR_hh * x_sect_hh * accp_hh
    print('No. of expected tt events: ', N_exp_tt)
    print('No. of expected hh events: ', N_exp_hh)

    sigma = N_exp_hh / (N_exp_tt)**(1/2)
    print("semi-lepton Sigma: " + str(sigma) + " with a cut > " + str(i))
    sigma_value.append(sigma)
    cut_value.append(i)

    # Store copies of the DataFrames in the dictionaries for each bin
    signal_events_dict[i] = hh_cut_df.copy()
    background_events_dict[i] = tt_cut_df.copy()

    if sigma > max_sigma:
        max_sigma = sigma
        cut_index = i

print('No. of tt events at maximum sigma: ', tt_cut.Count().GetValue())
print('No. of hh events at maximum sigma: ', hh_cut.Count().GetValue())
print('The maximum sigma value is:')
print("semi-lepton Sigma: " + str(max_sigma) + " with a cut > " + str(cut_index))
bb = pd.DataFrame({"cut_value" : cut_value, "sigma_value" : sigma_value})
bb.to_csv("/localdata/Athar/CNN/plot_files/plot_data/feature_3.csv", index=False)


# Save the data for each bin to separate CSV files
for i in cut:
    signal_events_dict[i].to_csv(f"/localdata/Athar/CNN/plot_files/cut_data/cut_3/signal_events_bin_{i}.csv", index=False)
    background_events_dict[i].to_csv(f"/localdata/Athar/CNN/plot_files/cut_data/cut_3/background_events_bin_{i}.csv", index=False)
# Out:
# number of tt events:  915
# number of hh events:  24300
# acceptance of hh:  0.027
# acceptance of tt:  0.0006535714285714286
# No. of expected tt events:  723871.2053571428
# No. of expected hh events:  303.588
# semi-lepton Sigma: 0.35682391215641135 with a cut > 0.9
# number of tt events:  864
# number of hh events:  23866
# acceptance of hh:  0.02651777777777778
# acceptance of tt:  0.0006171428571428571
# No. of expected tt events:  683524.2857142857
# No. of expected hh events:  298.1658933333334
# semi-lepton Sigma: 0.36064589139864117 with a cut > 0.9031034482758621
# number of tt events:  826
# number of hh events:  23488
# acceptance of hh:  0.02609777777777778
# acceptance of tt:  0.00059
# No. of expected tt events:  653461.875
# No. of expected hh events:  293.44341333333335
# semi-lepton Sigma: 0.36300636363956235 with a cut > 0.9062068965517242
# number of tt events:  792
# number of hh events:  23049
# acceptance of hh:  0.02561
# acceptance of tt:  0.0005657142857142857
# No. of expected tt events:  626563.9285714285
# No. of expected hh events:  287.95884
# semi-lepton Sigma: 0.3637874570068524 with a cut > 0.9093103448275862
# number of tt events:  756
# number of hh events:  22631
# acceptance of hh:  0.025145555555555556
# acceptance of tt:  0.00054
# No. of expected tt events:  598083.75
# No. of expected hh events:  282.73662666666667
# semi-lepton Sigma: 0.3655956929853348 with a cut > 0.9124137931034483
# number of tt events:  708
# number of hh events:  22205
# acceptance of hh:  0.024672222222222224
# acceptance of tt:  0.0005057142857142857
# No. of expected tt events:  560110.1785714285
# No. of expected hh events:  277.41446666666667
# semi-lepton Sigma: 0.37067421161966463 with a cut > 0.9155172413793103
# number of tt events:  660
# number of hh events:  21744
# acceptance of hh:  0.02416
# acceptance of tt:  0.0004714285714285714
# No. of expected tt events:  522136.60714285716
# No. of expected hh events:  271.65504
# semi-lepton Sigma: 0.37594619660887674 with a cut > 0.9186206896551724
# number of tt events:  632
# number of hh events:  21285
# acceptance of hh:  0.02365
# acceptance of tt:  0.00045142857142857143
# No. of expected tt events:  499985.35714285716
# No. of expected hh events:  265.92060000000004
# semi-lepton Sigma: 0.3760740258729451 with a cut > 0.9217241379310345
# number of tt events:  597
# number of hh events:  20811
# acceptance of hh:  0.023123333333333333
# acceptance of tt:  0.0004264285714285714
# No. of expected tt events:  472296.2946428571
# No. of expected hh events:  259.99876
# semi-lepton Sigma: 0.3783240999390181 with a cut > 0.9248275862068965
# number of tt events:  569
# number of hh events:  20293
# acceptance of hh:  0.022547777777777778
# acceptance of tt:  0.0004064285714285714
# No. of expected tt events:  450145.04464285716
# No. of expected hh events:  253.52721333333332
# semi-lepton Sigma: 0.3778751617150861 with a cut > 0.9279310344827586
# number of tt events:  526
# number of hh events:  19788
# acceptance of hh:  0.021986666666666668
# acceptance of tt:  0.0003757142857142857
# No. of expected tt events:  416127.0535714286
# No. of expected hh events:  247.21808000000001
# semi-lepton Sigma: 0.3832368426293342 with a cut > 0.9310344827586207
# number of tt events:  493
# number of hh events:  19283
# acceptance of hh:  0.021425555555555555
# acceptance of tt:  0.00035214285714285713
# No. of expected tt events:  390020.2232142857
# No. of expected hh events:  240.90894666666665
# semi-lepton Sigma: 0.38575304728270765 with a cut > 0.9341379310344827
# number of tt events:  457
# number of hh events:  18705
# acceptance of hh:  0.020783333333333334
# acceptance of tt:  0.0003264285714285714
# No. of expected tt events:  361540.04464285716
# No. of expected hh events:  233.6878
# semi-lepton Sigma: 0.38864925216188656 with a cut > 0.9372413793103448
# number of tt events:  431
# number of hh events:  18151
# acceptance of hh:  0.020167777777777778
# acceptance of tt:  0.00030785714285714287
# No. of expected tt events:  340971.0267857143
# No. of expected hh events:  226.76649333333333
# semi-lepton Sigma: 0.38834717081118997 with a cut > 0.9403448275862069
# number of tt events:  403
# number of hh events:  17574
# acceptance of hh:  0.019526666666666668
# acceptance of tt:  0.00028785714285714287
# No. of expected tt events:  318819.7767857143
# No. of expected hh events:  219.55784000000003
# semi-lepton Sigma: 0.3888448244745517 with a cut > 0.943448275862069
# number of tt events:  383
# number of hh events:  16964
# acceptance of hh:  0.018848888888888887
# acceptance of tt:  0.0002735714285714286
# No. of expected tt events:  302997.45535714284
# No. of expected hh events:  211.93690666666666
# semi-lepton Sigma: 0.38502337862639424 with a cut > 0.9465517241379311
# number of tt events:  353
# number of hh events:  16412
# acceptance of hh:  0.018235555555555557
# acceptance of tt:  0.00025214285714285714
# No. of expected tt events:  279263.9732142857
# No. of expected hh events:  205.04058666666668
# semi-lepton Sigma: 0.38800058417987127 with a cut > 0.9496551724137932
# number of tt events:  324
# number of hh events:  15762
# acceptance of hh:  0.017513333333333332
# acceptance of tt:  0.00023142857142857142
# No. of expected tt events:  256321.60714285713
# No. of expected hh events:  196.91992
# semi-lepton Sigma: 0.3889529251132017 with a cut > 0.9527586206896552
# number of tt events:  293
# number of hh events:  15046
# acceptance of hh:  0.01671777777777778
# acceptance of tt:  0.0002092857142857143
# No. of expected tt events:  231797.00892857142
# No. of expected hh events:  187.97469333333336
# semi-lepton Sigma: 0.3904320590972155 with a cut > 0.9558620689655173
# number of tt events:  260
# number of hh events:  14400
# acceptance of hh:  0.016
# acceptance of tt:  0.00018571428571428572
# No. of expected tt events:  205690.17857142858
# No. of expected hh events:  179.904
# semi-lepton Sigma: 0.39667427986936593 with a cut > 0.9589655172413794
# number of tt events:  231
# number of hh events:  13687
# acceptance of hh:  0.015207777777777778
# acceptance of tt:  0.000165
# No. of expected tt events:  182747.8125
# No. of expected hh events:  170.99625333333333
# semi-lepton Sigma: 0.4000004695952052 with a cut > 0.9620689655172414
# number of tt events:  208
# number of hh events:  12885
# acceptance of hh:  0.014316666666666667
# acceptance of tt:  0.00014857142857142857
# No. of expected tt events:  164552.14285714287
# No. of expected hh events:  160.9766
# semi-lepton Sigma: 0.39683592312450516 with a cut > 0.9651724137931035
# number of tt events:  173
# number of hh events:  12122
# acceptance of hh:  0.01346888888888889
# acceptance of tt:  0.00012357142857142856
# No. of expected tt events:  136863.08035714284
# No. of expected hh events:  151.44418666666667
# semi-lepton Sigma: 0.40936381562568064 with a cut > 0.9682758620689655
# number of tt events:  147
# number of hh events:  11285
# acceptance of hh:  0.01253888888888889
# acceptance of tt:  0.000105
# No. of expected tt events:  116294.0625
# No. of expected hh events:  140.98726666666667
# semi-lepton Sigma: 0.4134291741545722 with a cut > 0.9713793103448276
# number of tt events:  121
# number of hh events:  10349
# acceptance of hh:  0.011498888888888888
# acceptance of tt:  8.642857142857143e-05
# No. of expected tt events:  95725.04464285714
# No. of expected hh events:  129.29350666666667
# semi-lepton Sigma: 0.41789187341210404 with a cut > 0.9744827586206897
# number of tt events:  95
# number of hh events:  9328
# acceptance of hh:  0.010364444444444445
# acceptance of tt:  6.785714285714286e-05
# No. of expected tt events:  75156.02678571429
# No. of expected hh events:  116.53781333333335
# semi-lepton Sigma: 0.42509398384466174 with a cut > 0.9775862068965517
# number of tt events:  78
# number of hh events:  8236
# acceptance of hh:  0.009151111111111112
# acceptance of tt:  5.5714285714285715e-05
# No. of expected tt events:  61707.05357142857
# No. of expected hh events:  102.89509333333334
# semi-lepton Sigma: 0.41421637198709804 with a cut > 0.9806896551724138
# number of tt events:  59
# number of hh events:  7154
# acceptance of hh:  0.007948888888888889
# acceptance of tt:  4.214285714285714e-05
# No. of expected tt events:  46675.84821428572
# No. of expected hh events:  89.37730666666667
# semi-lepton Sigma: 0.4136958400786329 with a cut > 0.9837931034482759
# number of tt events:  45
# number of hh events:  5844
# acceptance of hh:  0.006493333333333334
# acceptance of tt:  3.2142857142857144e-05
# No. of expected tt events:  35600.22321428572
# No. of expected hh events:  73.01104000000001
# semi-lepton Sigma: 0.38695652496607125 with a cut > 0.9868965517241379
# number of tt events:  27
# number of hh events:  4553
# acceptance of hh:  0.005058888888888889
# acceptance of tt:  1.9285714285714285e-05
# No. of expected tt events:  21360.133928571428
# No. of expected hh events:  56.882146666666664
# semi-lepton Sigma: 0.3892010400082815 with a cut > 0.99
# No. of tt events at maximum sigma:  27
# No. of hh events at maximum sigma:  4553
# The maximum sigma value is:
# semi-lepton Sigma: 0.42509398384466174 with a cut > 0.9775862068965517

# %%
#trial 3 (signal) Using variables m,pt,eta,phi,P,pair_dr,Hness,Tness

cut = np.linspace(0.97, 0.99,10)
Lumi = 3000
# TTbar variables
BR_tt = 0.375  # Total branching ratio for the ttbar process
x_sect_tt = 984500  # fb
total_events_tt = 1_400_000

# HH variables
BR_hh = 0.0937  # Total branching ratio for the hh process
x_sect_hh = 40  # fb
total_events_hh = 900_000

max_sigma = 0
cut_index = 0
sigma_value = []
cut_value = []
signal_events_dict = {}  # Dictionary to store signal event rows for each bin
background_events_dict = {}  # Dictionary to store background event rows for each bin

for i in cut:
    prob_sig_cut = 'prob_sig > {}'.format(i)
    tt_cut = tt_trial_3.Filter(prob_sig_cut)  # Filter signal events
    hh_cut = hh_trial_3.Filter(prob_sig_cut)  # Filter background events

    # Extract relevant data from RDataFrame and convert to pandas DataFrame
    tt_cut_data = tt_cut.AsNumpy()
    tt_cut_df = pd.DataFrame(tt_cut_data)

    hh_cut_data = hh_cut.AsNumpy()
    hh_cut_df = pd.DataFrame(hh_cut_data)

    num_hh = hh_cut.Count().GetValue()
    num_tt = tt_cut.Count().GetValue()
    print('number of tt events: ', num_tt)
    print('number of hh events: ', num_hh)

    accp_tt = num_tt / total_events_tt
    accp_hh = num_hh / total_events_hh
    print('acceptance of hh: ', accp_hh)
    print('acceptance of tt: ', accp_tt)

    # Calculate expected events
    N_exp_tt = Lumi * BR_tt * x_sect_tt * accp_tt
    N_exp_hh = Lumi * BR_hh * x_sect_hh * accp_hh
    print('No. of expected tt events: ', N_exp_tt)
    print('No. of expected hh events: ', N_exp_hh)

    sigma = N_exp_hh / (N_exp_tt)**(1/2)
    print("semi-lepton Sigma: " + str(sigma) + " with a cut > " + str(i))
    sigma_value.append(sigma)
    cut_value.append(i)

    # Store copies of the DataFrames in the dictionaries for each bin
    signal_events_dict[i] = hh_cut_df.copy()
    background_events_dict[i] = tt_cut_df.copy()

    if sigma > max_sigma:
        max_sigma = sigma
        cut_index = i

print('No. of tt events at maximum sigma: ', tt_cut.Count().GetValue())
print('No. of hh events at maximum sigma: ', hh_cut.Count().GetValue())
print('The maximum sigma value is:')
print("semi-lepton Sigma: " + str(max_sigma) + " with a cut > " + str(cut_index))
bb = pd.DataFrame({"cut_value" : cut_value, "sigma_value" : sigma_value})
bb.to_csv("/localdata/Athar/CNN/plot_files/plot_data/feature_4.csv", index=False)


# Save the data for each bin to separate CSV files
for i in cut:
    signal_events_dict[i].to_csv(f"/localdata/Athar/CNN/plot_files/cut_data/cut_4/signal_events_bin_{i}.csv", index=False)
    background_events_dict[i].to_csv(f"/localdata/Athar/CNN/plot_files/cut_data/cut_4/background_events_bin_{i}.csv", index=False)
# Out:
# number of tt events:  200
# number of hh events:  13159
# acceptance of hh:  0.01462111111111111
# acceptance of tt:  0.00014285714285714287
# No. of expected tt events:  158223.2142857143
# No. of expected hh events:  164.39977333333334
# semi-lepton Sigma: 0.4133006734742924 with a cut > 0.97
# number of tt events:  180
# number of hh events:  12514
# acceptance of hh:  0.013904444444444445
# acceptance of tt:  0.00012857142857142858
# No. of expected tt events:  142400.89285714287
# No. of expected hh events:  156.34157333333334
# semi-lepton Sigma: 0.41430304187417993 with a cut > 0.9722222222222222
# number of tt events:  155
# number of hh events:  11865
# acceptance of hh:  0.013183333333333333
# acceptance of tt:  0.00011071428571428571
# No. of expected tt events:  122622.99107142857
# No. of expected hh events:  148.2334
# semi-lepton Sigma: 0.42331154906342494 with a cut > 0.9744444444444444
# number of tt events:  131
# number of hh events:  11121
# acceptance of hh:  0.012356666666666667
# acceptance of tt:  9.357142857142857e-05
# No. of expected tt events:  103636.20535714286
# No. of expected hh events:  138.93836
# semi-lepton Sigma: 0.43158507422632325 with a cut > 0.9766666666666667
# number of tt events:  113
# number of hh events:  10373
# acceptance of hh:  0.011525555555555556
# acceptance of tt:  8.071428571428571e-05
# No. of expected tt events:  89396.11607142857
# No. of expected hh events:  129.59334666666666
# semi-lepton Sigma: 0.4334344034084902 with a cut > 0.9788888888888889
# number of tt events:  94
# number of hh events:  9570
# acceptance of hh:  0.010633333333333333
# acceptance of tt:  6.714285714285714e-05
# No. of expected tt events:  74364.91071428571
# No. of expected hh events:  119.5612
# semi-lepton Sigma: 0.4384360282380004 with a cut > 0.981111111111111
# number of tt events:  76
# number of hh events:  8753
# acceptance of hh:  0.009725555555555555
# acceptance of tt:  5.428571428571429e-05
# No. of expected tt events:  60124.821428571435
# No. of expected hh events:  109.35414666666667
# semi-lepton Sigma: 0.44597278399893553 with a cut > 0.9833333333333333
# number of tt events:  62
# number of hh events:  7936
# acceptance of hh:  0.008817777777777779
# acceptance of tt:  4.428571428571428e-05
# No. of expected tt events:  49049.19642857143
# No. of expected hh events:  99.14709333333334
# semi-lepton Sigma: 0.4476762328378874 with a cut > 0.9855555555555555
# number of tt events:  54
# number of hh events:  6994
# acceptance of hh:  0.0077711111111111114
# acceptance of tt:  3.857142857142857e-05
# No. of expected tt events:  42720.267857142855
# No. of expected hh events:  87.37837333333334
# semi-lepton Sigma: 0.4227532664781859 with a cut > 0.9877777777777778
# number of tt events:  39
# number of hh events:  5917
# acceptance of hh:  0.006574444444444444
# acceptance of tt:  2.7857142857142858e-05
# No. of expected tt events:  30853.526785714286
# No. of expected hh events:  73.92305333333333
# semi-lepton Sigma: 0.42085015323118546 with a cut > 0.99
# No. of tt events at maximum sigma:  39
# No. of hh events at maximum sigma:  5917
# The maximum sigma value is:
# semi-lepton Sigma: 0.4476762328378874 with a cut > 0.9855555555555555

# %%
#trial 4 (signal) Using variables m,pt,eta,phi,P,pair_dr,Hness,Tness

cut = np.linspace(0.97, 0.99,10)
Lumi = 3000
# TTbar variables
BR_tt = 0.375  # Total branching ratio for the ttbar process
x_sect_tt = 984500  # fb
total_events_tt = 1_400_000

# HH variables
BR_hh = 0.0937  # Total branching ratio for the hh process
x_sect_hh = 40  # fb
total_events_hh = 900_000

max_sigma = 0
cut_index = 0
sigma_value = []
cut_value = []
signal_events_dict = {}  # Dictionary to store signal event rows for each bin
background_events_dict = {}  # Dictionary to store background event rows for each bin

for i in cut:
    prob_sig_cut = 'prob_sig > {}'.format(i)
    tt_cut = tt_trial_4.Filter(prob_sig_cut)  # Filter signal events
    hh_cut = hh_trial_4.Filter(prob_sig_cut)  # Filter background events

    # Extract relevant data from RDataFrame and convert to pandas DataFrame
    tt_cut_data = tt_cut.AsNumpy()
    tt_cut_df = pd.DataFrame(tt_cut_data)

    hh_cut_data = hh_cut.AsNumpy()
    hh_cut_df = pd.DataFrame(hh_cut_data)

    num_hh = hh_cut.Count().GetValue()
    num_tt = tt_cut.Count().GetValue()
    print('number of tt events: ', num_tt)
    print('number of hh events: ', num_hh)

    accp_tt = num_tt / total_events_tt
    accp_hh = num_hh / total_events_hh
    print('acceptance of hh: ', accp_hh)
    print('acceptance of tt: ', accp_tt)

    # Calculate expected events
    N_exp_tt = Lumi * BR_tt * x_sect_tt * accp_tt
    N_exp_hh = Lumi * BR_hh * x_sect_hh * accp_hh
    print('No. of expected tt events: ', N_exp_tt)
    print('No. of expected hh events: ', N_exp_hh)

    sigma = N_exp_hh / (N_exp_tt)**(1/2)
    print("semi-lepton Sigma: " + str(sigma) + " with a cut > " + str(i))
    sigma_value.append(sigma)
    cut_value.append(i)

    # Store copies of the DataFrames in the dictionaries for each bin
    signal_events_dict[i] = hh_cut_df.copy()
    background_events_dict[i] = tt_cut_df.copy()

    if sigma > max_sigma:
        max_sigma = sigma
        cut_index = i

print('No. of tt events at maximum sigma: ', tt_cut.Count().GetValue())
print('No. of hh events at maximum sigma: ', hh_cut.Count().GetValue())
print('The maximum sigma value is:')
print("semi-lepton Sigma: " + str(max_sigma) + " with a cut > " + str(cut_index))
bb = pd.DataFrame({"cut_value" : cut_value, "sigma_value" : sigma_value})
bb.to_csv("/localdata/Athar/CNN/plot_files/plot_data/feature_5.csv", index=False)


# Save the data for each bin to separate CSV files
for i in cut:
    signal_events_dict[i].to_csv(f"/localdata/Athar/CNN/plot_files/cut_data/cut_5/signal_events_bin_{i}.csv", index=False)
    background_events_dict[i].to_csv(f"/localdata/Athar/CNN/plot_files/cut_data/cut_5/background_events_bin_{i}.csv", index=False)
# Out:
# number of tt events:  238
# number of hh events:  14578
# acceptance of hh:  0.016197777777777776
# acceptance of tt:  0.00017
# No. of expected tt events:  188285.625
# No. of expected hh events:  182.1278133333333
# semi-lepton Sigma: 0.41972775774035526 with a cut > 0.97
# number of tt events:  212
# number of hh events:  13969
# acceptance of hh:  0.01552111111111111
# acceptance of tt:  0.00015142857142857143
# No. of expected tt events:  167716.60714285713
# No. of expected hh events:  174.51937333333333
# semi-lepton Sigma: 0.4261432470965824 with a cut > 0.9722222222222222
# number of tt events:  192
# number of hh events:  13254
# acceptance of hh:  0.014726666666666667
# acceptance of tt:  0.00013714285714285713
# No. of expected tt events:  151894.2857142857
# No. of expected hh events:  165.58664000000002
# semi-lepton Sigma: 0.4248685414234925 with a cut > 0.9744444444444444
# number of tt events:  167
# number of hh events:  12612
# acceptance of hh:  0.014013333333333333
# acceptance of tt:  0.00011928571428571428
# No. of expected tt events:  132116.38392857142
# No. of expected hh events:  157.56591999999998
# semi-lepton Sigma: 0.4334948580186222 with a cut > 0.9766666666666667
# number of tt events:  146
# number of hh events:  11803
# acceptance of hh:  0.013114444444444444
# acceptance of tt:  0.00010428571428571428
# No. of expected tt events:  115502.94642857142
# No. of expected hh events:  147.45881333333332
# semi-lepton Sigma: 0.43388456728260716 with a cut > 0.9788888888888889
# number of tt events:  120
# number of hh events:  10986
# acceptance of hh:  0.012206666666666666
# acceptance of tt:  8.571428571428571e-05
# No. of expected tt events:  94933.92857142857
# No. of expected hh events:  137.25176
# semi-lepton Sigma: 0.4454584438029711 with a cut > 0.981111111111111
# number of tt events:  103
# number of hh events:  10147
# acceptance of hh:  0.011274444444444445
# acceptance of tt:  7.357142857142857e-05
# No. of expected tt events:  81484.95535714286
# No. of expected hh events:  126.76985333333333
# semi-lepton Sigma: 0.44409641968518165 with a cut > 0.9833333333333333
# number of tt events:  94
# number of hh events:  9219
# acceptance of hh:  0.010243333333333333
# acceptance of tt:  6.714285714285714e-05
# No. of expected tt events:  74364.91071428571
# No. of expected hh events:  115.17604
# semi-lepton Sigma: 0.4223554591772336 with a cut > 0.9855555555555555
# number of tt events:  74
# number of hh events:  8171
# acceptance of hh:  0.009078888888888888
# acceptance of tt:  5.2857142857142855e-05
# No. of expected tt events:  58542.58928571428
# No. of expected hh events:  102.08302666666665
# semi-lepton Sigma: 0.4219078194815286 with a cut > 0.9877777777777778
# number of tt events:  57
# number of hh events:  7004
# acceptance of hh:  0.0077822222222222225
# acceptance of tt:  4.0714285714285717e-05
# No. of expected tt events:  45093.61607142857
# No. of expected hh events:  87.50330666666667
# semi-lepton Sigma: 0.4120661437858558 with a cut > 0.99
# No. of tt events at maximum sigma:  57
# No. of hh events at maximum sigma:  7004
# The maximum sigma value is:
# semi-lepton Sigma: 0.4454584438029711 with a cut > 0.981111111111111
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-b778e84d158a> in <module>
#      71 # Save the data for each bin to separate CSV files
#      72 for i in cut:
# ---> 73     signal_events_dict[i].to_csv(f"/localdata/Athar/CNN/plot_files/cut_data/cut_5/signal_events_bin_{i}.csv", index=False)
#      74     background_events_dict[i].to_csv(f"/localdata/Athar/CNN/plot_files/cut_data/cut_5/background_events_bin_{i}.csv", index=False)
#
# /usr/local/lib64/python3.6/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# /usr/local/lib64/python3.6/site-packages/pandas/io/formats/csvs.py in save(self)
#     188                 encoding=self.encoding,
#     189                 errors=self.errors,
# --> 190                 compression=dict(self.compression_args, method=self.compression),
#     191             )
#     192             close = True
#
# /usr/local/lib64/python3.6/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '/localdata/Athar/CNN/plot_files/cut_data/cut_5/signal_events_bin_0.97.csv'

# %%
#trial 5b (signal) Using variables m,pt,eta,phi,P,pair_dr,Hness,Tness

cut = np.linspace(0.96, 0.97,10)
Lumi = 3000
# TTbar variables
BR_tt = 0.375  # Total branching ratio for the ttbar process
x_sect_tt = 984500  # fb
total_events_tt = 1_400_000

# HH variables
BR_hh = 0.0937  # Total branching ratio for the hh process
x_sect_hh = 40  # fb
total_events_hh = 900_000

max_sigma = 0
cut_index = 0
sigma_value = []
cut_value = []
signal_events_dict = {}  # Dictionary to store signal event rows for each bin
background_events_dict = {}  # Dictionary to store background event rows for each bin

for i in cut:
    prob_sig_cut = 'prob_sig > {}'.format(i)
    tt_cut = tt_trial_5.Filter(prob_sig_cut)  # Filter signal events
    hh_cut = hh_trial_5.Filter(prob_sig_cut)  # Filter background events

    # Extract relevant data from RDataFrame and convert to pandas DataFrame
    tt_cut_data = tt_cut.AsNumpy()
    tt_cut_df = pd.DataFrame(tt_cut_data)

    hh_cut_data = hh_cut.AsNumpy()
    hh_cut_df = pd.DataFrame(hh_cut_data)

    num_hh = hh_cut.Count().GetValue()
    num_tt = tt_cut.Count().GetValue()
    print('number of tt events: ', num_tt)
    print('number of hh events: ', num_hh)

    accp_tt = num_tt / total_events_tt
    accp_hh = num_hh / total_events_hh
    print('acceptance of hh: ', accp_hh)
    print('acceptance of tt: ', accp_tt)

    # Calculate expected events
    N_exp_tt = Lumi * BR_tt * x_sect_tt * accp_tt
    N_exp_hh = Lumi * BR_hh * x_sect_hh * accp_hh
    print('No. of expected tt events: ', N_exp_tt)
    print('No. of expected hh events: ', N_exp_hh)

    sigma = N_exp_hh / (N_exp_tt)**(1/2)
    print("semi-lepton Sigma: " + str(sigma) + " with a cut > " + str(i))
    sigma_value.append(sigma)
    cut_value.append(i)

    # Store copies of the DataFrames in the dictionaries for each bin
    signal_events_dict[i] = hh_cut_df.copy()
    background_events_dict[i] = tt_cut_df.copy()

    if sigma > max_sigma:
        max_sigma = sigma
        cut_index = i

print('No. of tt events at maximum sigma: ', tt_cut.Count().GetValue())
print('No. of hh events at maximum sigma: ', hh_cut.Count().GetValue())
print('The maximum sigma value is:')
print("semi-lepton Sigma: " + str(max_sigma) + " with a cut > " + str(cut_index))
bb = pd.DataFrame({"cut_value" : cut_value, "sigma_value" : sigma_value})
bb.to_csv("/localdata/Athar/CNN/plot_files/plot_data/feature_7b.csv", index=False)


# Save the data for each bin to separate CSV files
for i in cut:
    signal_events_dict[i].to_csv(f"/localdata/Athar/CNN/plot_files/cut_data/cut_6/signal_events_bin_{i}.csv", index=False)
    background_events_dict[i].to_csv(f"/localdata/Athar/CNN/plot_files/cut_data/cut_6/background_events_bin_{i}.csv", index=False)
# Out:
# number of tt events:  253
# number of hh events:  13723
# acceptance of hh:  0.015247777777777778
# acceptance of tt:  0.0001807142857142857
# No. of expected tt events:  200152.36607142855
# No. of expected hh events:  171.44601333333335
# semi-lepton Sigma: 0.3832189941443403 with a cut > 0.96
# number of tt events:  239
# number of hh events:  13469
# acceptance of hh:  0.014965555555555555
# acceptance of tt:  0.0001707142857142857
# No. of expected tt events:  189076.74107142855
# No. of expected hh events:  168.27270666666666
# semi-lepton Sigma: 0.3869854408494273 with a cut > 0.961111111111111
# number of tt events:  232
# number of hh events:  13243
# acceptance of hh:  0.014714444444444445
# acceptance of tt:  0.00016571428571428572
# No. of expected tt events:  183538.92857142858
# No. of expected hh events:  165.44921333333335
# semi-lepton Sigma: 0.3861896323083258 with a cut > 0.9622222222222222
# number of tt events:  222
# number of hh events:  12979
# acceptance of hh:  0.014421111111111112
# acceptance of tt:  0.00015857142857142857
# No. of expected tt events:  175627.76785714287
# No. of expected hh events:  162.15097333333335
# semi-lepton Sigma: 0.3869215947258749 with a cut > 0.9633333333333333
# number of tt events:  208
# number of hh events:  12705
# acceptance of hh:  0.014116666666666666
# acceptance of tt:  0.00014857142857142857
# No. of expected tt events:  164552.14285714287
# No. of expected hh events:  158.7278
# semi-lepton Sigma: 0.3912922315325447 with a cut > 0.9644444444444444
# number of tt events:  198
# number of hh events:  12422
# acceptance of hh:  0.013802222222222223
# acceptance of tt:  0.00014142857142857143
# No. of expected tt events:  156640.98214285713
# No. of expected hh events:  155.1921866666667
# semi-lepton Sigma: 0.39211833840419286 with a cut > 0.9655555555555555
# number of tt events:  189
# number of hh events:  12116
# acceptance of hh:  0.013462222222222223
# acceptance of tt:  0.000135
# No. of expected tt events:  149520.9375
# No. of expected hh events:  151.36922666666666
# semi-lepton Sigma: 0.3914592741116447 with a cut > 0.9666666666666667
# number of tt events:  181
# number of hh events:  11815
# acceptance of hh:  0.013127777777777778
# acceptance of tt:  0.0001292857142857143
# No. of expected tt events:  143192.00892857145
# No. of expected hh events:  147.60873333333333
# semi-lepton Sigma: 0.390079082470555 with a cut > 0.9677777777777777
# number of tt events:  172
# number of hh events:  11552
# acceptance of hh:  0.012835555555555555
# acceptance of tt:  0.00012285714285714287
# No. of expected tt events:  136071.9642857143
# No. of expected hh events:  144.32298666666665
# semi-lepton Sigma: 0.39124714428310964 with a cut > 0.9688888888888889
# number of tt events:  159
# number of hh events:  11223
# acceptance of hh:  0.01247
# acceptance of tt:  0.00011357142857142858
# No. of expected tt events:  125787.45535714287
# No. of expected hh events:  140.21268
# semi-lepton Sigma: 0.3953380580540853 with a cut > 0.97
# No. of tt events at maximum sigma:  159
# No. of hh events at maximum sigma:  11223
# The maximum sigma value is:
# semi-lepton Sigma: 0.3953380580540853 with a cut > 0.97
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-91bc393ff5a0> in <module>
#      71 # Save the data for each bin to separate CSV files
#      72 for i in cut:
# ---> 73     signal_events_dict[i].to_csv(f"/localdata/Athar/CNN/plot_files/cut_data/cut_6/signal_events_bin_{i}.csv", index=False)
#      74     background_events_dict[i].to_csv(f"/localdata/Athar/CNN/plot_files/cut_data/cut_6/background_events_bin_{i}.csv", index=False)
#
# /usr/local/lib64/python3.6/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# /usr/local/lib64/python3.6/site-packages/pandas/io/formats/csvs.py in save(self)
#     188                 encoding=self.encoding,
#     189                 errors=self.errors,
# --> 190                 compression=dict(self.compression_args, method=self.compression),
#     191             )
#     192             close = True
#
# /usr/local/lib64/python3.6/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '/localdata/Athar/CNN/plot_files/cut_data/cut_6/signal_events_bin_0.96.csv'
